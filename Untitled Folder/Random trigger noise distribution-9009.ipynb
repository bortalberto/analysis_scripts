# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import numpy as np
import ROOT as R
from tqdm import tqdm
import pickle
import root_pandas
# %jsroot

# %%
f=R.TFile("/home/alb/srv_lab/9013/SubRUN_1_GEMROC_0_TM.root")

# %%
hit_counter={}

# %%
for entrynum in tqdm(range (0,f.tree.GetEntries())):
    f.tree.GetEntry(entrynum)
    if getattr(f.tree ,"count"):
        count=getattr(f.tree ,"count")
        tiger=getattr(f.tree ,"tiger")
        gemroc=getattr(f.tree ,"gemroc")
        channel=getattr(f.tree ,"channel")

        delta_coarse=getattr(f.tree ,"delta_coarse")
        l1ts_min_tcoarse=getattr(f.tree ,"l1ts_min_tcoarse")
        if (delta_coarse==21 or delta_coarse==22) and not (channel==28 and tiger==2) and (tiger== 2 or tiger ==3):
            try:
                hit_counter[count][gemroc*8+tiger]+=1
            except KeyError:
                hit_counter[count]=np.zeros((8*11))
                hit_counter[count][gemroc*8+tiger]+=1
# Out:
# 100%|██████████| 195838/195838 [00:05<00:00, 38244.21it/s]

# %%
(hit_counter.keys())
# Out:
# dict_keys([409, 412, 413, 414, 415, 416, 417, 421, 422, 423, 427, 429, 431, 437, 439, 442, 446, 447, 448, 451, 454, 455, 456, 459, 463, 465, 466, 467, 469, 470, 472, 473, 474, 476, 477, 478, 484, 485, 489, 491, 492, 493, 496, 497, 499, 501, 502, 506, 507, 508, 510, 511, 512, 514, 516, 521, 525, 530, 531, 532, 535, 536, 538, 542, 544, 547, 548, 551, 553, 563, 568, 570, 571, 572, 580, 583, 584, 585, 588, 589, 590, 591, 592, 598, 599, 600, 604, 605, 606, 607, 610, 611, 612, 613, 614, 615, 616, 619, 620, 623, 624, 625, 626, 628, 630, 633, 636, 638, 642, 644, 647, 649, 650, 652, 654, 658, 660, 662, 664, 667, 669, 670, 672, 675, 676, 678, 680, 683, 686, 687, 688, 690, 691, 694, 709, 711, 713, 714, 717, 720, 721, 728, 729, 730, 731, 732, 734, 735, 736, 738, 740, 741, 743, 744, 745, 746, 747, 748, 749, 750, 751, 752, 753, 757, 759, 761, 762, 767, 768, 769, 770, 774, 775, 779, 785, 789, 792, 793, 794, 795, 796, 801, 802, 803, 808, 809, 811, 812, 814, 815, 819, 821, 824, 829, 832, 838, 841, 842, 844, 846, 848, 849, 850, 852, 853, 858, 861, 866, 872, 877, 879, 881, 882, 883, 885, 888, 890, 891, 892, 896, 898, 900, 901, 902, 904, 905, 906, 907, 909, 910, 911, 913, 916, 917, 919, 920, 923, 924, 925, 932, 933, 935, 936, 937, 939, 941, 942, 946, 947, 949, 951, 952, 953, 955, 957, 961, 962, 963, 965, 967, 969, 970, 971, 974, 977, 979, 981, 982, 985, 989, 995, 997, 998, 999, 1000, 1001, 1003, 1006, 1011, 1012, 1014, 1018, 1020, 1024, 1028, 1031, 1032, 1039, 1041, 1043, 1046, 1051, 1052, 1056, 1059, 1062, 1063, 1064, 1068, 1070, 1072, 1075, 1076, 1079, 1080, 1081, 1088, 1089, 1091, 1092, 1096, 1099, 1100, 1101, 1103, 1107, 1108, 1109, 1117, 1118, 1119, 1122, 1124, 1126, 1130, 1131, 1133, 1135, 1138, 1139, 1141, 1142, 1144, 1145, 1148, 1149, 1152, 1153, 1156, 1157, 1158, 1161, 1162, 1163, 1166, 1167, 1169, 1172, 1175, 1177, 1178, 1182, 1183, 1186, 1189, 1191, 1193, 1197, 1201, 1202, 1204, 1205, 1206, 1207, 1209, 1212, 1216, 1220, 1222, 1224, 1225, 1230, 1232, 1235, 1238, 1244, 1245, 1247, 1249, 1250, 1251, 1252, 1253, 1255, 1260, 1264, 1267, 1273, 1274, 1275, 1278, 1279, 1280, 1281, 1285, 1291, 1293, 1295, 1298, 1306, 1308, 1309, 1312, 1319, 1320, 1323, 1324, 1326, 1327, 1333, 1335, 1337, 1338, 1340, 1341, 1343, 1344, 1346, 1347, 1348, 1350, 1352, 1355, 1358, 1359, 1360, 1362, 1363, 1365, 1367, 1371, 1372, 1373, 1374, 1375, 1376, 1377, 1378, 1380, 1382, 1387, 1388, 1390, 1391, 1392, 1395, 1396, 1397, 1399, 1400, 1401, 1404, 1406, 1407, 1408, 1409, 1410, 1414, 1415, 1418, 1420, 1421, 1422, 1423, 1424, 1426, 1428, 1430, 1432, 1435, 1442, 1446, 1447, 1449, 1450, 1451, 1453, 1456, 1457, 1458, 1459, 1463, 1464, 1468, 1469, 1470, 1472, 1479, 1482, 1483, 1487, 1488, 1493, 1494, 1495, 1496, 1498, 1500, 1505, 1506, 1508, 1509, 1510, 1512, 1518, 1519, 1521, 1526, 1528, 1537, 1539, 1545, 1546, 1552, 1554, 1556, 1558, 1559, 1565, 1567, 1568, 1573, 1575, 1582, 1586, 1591, 1592, 1595, 1596, 1597, 1598, 1600, 1601, 1603, 1605, 1606, 1608, 1610, 1612, 1616, 1617, 1622, 1624, 1627, 1630, 1632, 1633, 1635, 1640, 1641, 1644, 1646, 1647, 1649, 1652, 1656, 1677, 1679, 1682, 1683, 1685, 1689, 1693, 1697, 1698, 1699, 1702, 1712, 1713, 1715, 1716, 1720, 1721, 1724, 1729, 1731, 1732, 1733, 1736, 1737, 1738, 1739, 1745, 1746, 1755, 1758, 1761, 1762, 1770, 1771, 1773, 1774, 1776, 1777, 1778, 1787, 1788, 1789, 1790, 1791, 1792, 1793, 1799, 1801, 1803, 1805, 1806, 1807, 1809, 1810, 1813, 1815, 1816, 1821, 1822, 1825, 1827, 1829, 1830, 1832, 1834, 1838, 1841, 1842, 1843, 1847, 1852, 1853, 1857, 1864, 1870, 1875, 1882, 1883, 1885, 1887, 1890, 1891, 1892, 1894, 1895, 1896, 1897, 1898, 1899, 1903, 1905, 1906, 1907, 1909, 1910, 1912, 1915, 1921, 1923, 1924, 1926, 1927, 1931, 1935, 1939, 1940, 1942, 1944, 1950, 1952, 1956, 1957, 1962, 1963, 1965, 1966, 1967, 1969, 1970, 1972, 1973, 1974, 1976, 1977, 1978, 1981, 1983, 1984, 1987, 1988, 1989, 1993, 1995, 1996, 1997, 1999, 2000, 2001, 2002, 2004, 2008, 2009, 2012, 2014, 2016, 2018, 2019, 2020, 2022, 2024, 2025, 2026, 2030, 2031, 203 ...

# %%
with open ("hit_count_save","wb") as fs:
    pickle.dump(hit_counter, fs)

# %%
with open ("hit_count_save","rb") as fs:
    hit_counter=pickle.load(fs)

# %%
data_4_pd={
    "L1":[],
    "Tiger":[],
    "Hits":[]    
}
for trigger in tqdm(range (406,60435)):
    try:
        matrix=hit_counter[trigger]
    except KeyError:
        matrix=np.zeros((8*11))
    for tiger in range(2,4):
        data_4_pd["L1"].append(trigger)
        data_4_pd["Tiger"].append(tiger)
        data_4_pd["Hits"].append(matrix[tiger])
# Out:
# 100%|██████████| 60029/60029 [00:00<00:00, 406679.70it/s]

# %%
counts_pd=pd.DataFrame(data_4_pd)

# %%
counts_tree=root_pandas.to_root(counts_pd,"counts_tree.root")

# %%
f2=R.TFile("/home/alb/Desktop/elaborazioni_e_dati/analisi_run/Untitled Folder/counts_tree.root")

# %%
f2.my_ttree.Show(1)
# Out:
# ======> EVENT:1
#  L1              = 406
#  Tiger           = 3
#  Hits            = 0
#  __index__       = 1

# %%
c=R.TCanvas()

# %%
h1_s=R.TH1F("h1_s","h1_s",60,0,60)
f2.my_ttree.Draw("Hits>>h1_s")
c.Draw()
# Out:
# <div id="root_plot_5"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
#        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-7.50000055879358,"fY1":-13214.1197345286,"fX2":67.5000005587936,"fY2":118927.069734529,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":9.27999986171722,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-0.00357193697057287,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-7.50000055879358,"fPixeltoXk":-7.50000055879358,"fPixeltoX":0.107758622295384,"fAbsPixeltoYk":118927.069734529,"fPixeltoYk":-13214.1197345286,"fPixeltoY":-279.960147180206,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":60,"fUymax":105712.95,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":60,"fY2":105712.95,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":50331656,"fName":"h1_s","fTitle":"h1_s","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":62,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":60,"fXmin":0,"fXmax":60,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":120058,"fTsumw":120057,"fTsumw2":120057,"fTsumwx":47346,"fTsumwx2":294886,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPaveStats","fUniqueID":0,"fBits":50331657,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":51.0000015199185,"fY1":89195.3028916136,"fX2":66.0000019669533,"fY2":110337.892734089,"fX1NDC":0.780000016093254,"fY1NDC":0.775000005960464,"fX2NDC":0.980000019073486,"fY2NDC":0.935000002384186,"fBorderSize":1,"fInit":1,"fShadowColor":1,"fCornerRadius":0,"fOption":"brNDC","fName":"stats","fTextAngle":0,"fTextSize" ...
#        Core.draw("root_plot_5", obj, "");
#      }
#  );
# </script>

# %%
def possoniana(x,par):
    return par[0]*R.TMath.Poisson(x[0],h1_s.GetMean())

# %% [markdown]
# # Hit per trigger, FEB singole

# %%
func_P=R.TF1("possoniana",possoniana,0, 20,1)
func_P.SetParameter(0,1)

scale=1/(func_P.Integral(0,20)/(h1_s.Integral()*h1_s.GetBinWidth(2)))
print(scale)
func_P.SetParameter(0,scale)

c.SetLogy()
func_P.Draw("same")
c.Draw("")
# Out:
# 187875.64724205807
# <div id="root_plot_6"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
#        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-7.50000055879358,"fY1":-0.998719771236055,"fX2":67.5000005587936,"fY2":5.97817756862918,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":9.27999986171722,"fYtoAbsPixelk":404.434811605289,"fYtoPixelk":404.434811605289,"fYtoPixel":-67.6518482367575,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-7.50000055879358,"fPixeltoXk":-7.50000055879358,"fPixeltoX":0.107758622295384,"fAbsPixeltoYk":5.97817756862918,"fPixeltoYk":-0.998719771236055,"fPixeltoY":-0.0147815621607314,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":-0.301029995663981,"fUxmax":60,"fUymax":5.28048779305711,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":1,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":-0.301029995663981,"fX2":60,"fY2":5.28048779305711,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":50331656,"fName":"h1_s","fTitle":"h1_s","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":62,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":60,"fXmin":0,"fXmax":60,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":120058,"fTsumw":120057,"fTsumw2":120057,"fTsumwx":47346,"fTsumwx2":294886,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPaveStats","fUniqueID":0,"fBits":50331657,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":51.0000015199185,"fY1":4.40837570874505,"fX2":66.0000019669533,"fY2":5.52467925817216,"fX1NDC":0.780000016093254,"fY1NDC":0.775000005960464,"fX2NDC":0.980000019073486,"fY2NDC":0.935000002384186,"fBorderSize":1,"fInit":1,"fShadowColor":1,"fCornerRadius":0,"fOption":" ...

# %%
hit_counter={}
for entrynum in tqdm(range (0,f.tree.GetEntries())):
    f.tree.GetEntry(entrynum)
    if getattr(f.tree ,"count"):
        count=getattr(f.tree ,"count")
        tiger=getattr(f.tree ,"tiger")
        gemroc=getattr(f.tree ,"gemroc")
        channel=getattr(f.tree ,"channel")

        delta_coarse=getattr(f.tree ,"delta_coarse")
        l1ts_min_tcoarse=getattr(f.tree ,"l1ts_min_tcoarse")
        if (delta_coarse==21 or delta_coarse==22) and (tiger== 0 or tiger ==1):
            try:
                hit_counter[count][gemroc*8+tiger]+=1
            except KeyError:
                hit_counter[count]=np.zeros((8*11))
                hit_counter[count][gemroc*8+tiger]+=1
# Out:
# 100%|██████████| 195838/195838 [00:05<00:00, 37131.74it/s]

# %%
data_4_pd={
    "L1":[],
    "Tiger":[],
    "Hits":[]    
}
for trigger in tqdm(range (406,60435)):
    try:
        matrix=hit_counter[trigger]
    except KeyError:
        matrix=np.zeros((8*11))
    for tiger in range(0,2):
        data_4_pd["L1"].append(trigger)
        data_4_pd["Tiger"].append(tiger)
        data_4_pd["Hits"].append(matrix[tiger])
# Out:
# 100%|██████████| 60029/60029 [00:00<00:00, 441119.31it/s]

# %%
counts_pd=pd.DataFrame(data_4_pd)

# %%
counts_tree=root_pandas.to_root(counts_pd,"counts_tree.root")
f=R.TFile("/home/alb/Desktop/elaborazioni_e_dati/analisi_run/Untitled Folder/counts_tree.root")
h1=R.TH1F("h1","h1",60,0,60)
f.my_ttree.Draw("Hits>>h1")
c.Draw()
def possoniana(x,par):
    return par[0]*R.TMath.Poisson(x[0],h1.GetMean())
# Out:
# <div id="root_plot_7"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
#        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-7.50000055879358,"fY1":-0.991837353022886,"fX2":67.5000005587936,"fY2":5.9162358088129,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":9.27999986171722,"fYtoAbsPixelk":404.231915578217,"fYtoPixelk":404.231915578217,"fYtoPixel":-68.3258542494313,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-7.50000055879358,"fPixeltoXk":-7.50000055879358,"fPixeltoX":0.107758622295384,"fAbsPixeltoYk":5.9162358088129,"fPixeltoYk":-0.991837353022886,"fPixeltoY":-0.0146357482242284,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":-0.301029995663981,"fUxmax":60,"fUymax":5.22542845145399,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":1,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":-0.301029995663981,"fX2":60,"fY2":5.22542845145399,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":50331656,"fName":"h1","fTitle":"h1","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":62,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":60,"fXmin":0,"fXmax":60,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":120058,"fTsumw":120056,"fTsumw2":120056,"fTsumwx":146622,"fTsumwx2":1920732,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPaveStats","fUniqueID":0,"fBits":50331657,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":51.0000015199185,"fY1":4.36191938857517,"fX2":66.0000019669533,"fY2":5.4672110697637,"fX1NDC":0.780000016093254,"fY1NDC":0.775000005960464,"fX2NDC":0.980000019073486,"fY2NDC":0.935000002384186,"fBorderSize":1,"fInit":1,"fShadowColor":1,"fCornerRadius":0,"fOption":"brNDC ...
#        Core.draw("root_plot_7", obj, "");
#      }
#  );
# </script>

# %%
func_P=R.TF1("possoniana",possoniana,0, 80,1)
func_P.SetParameter(0,1)

scale=1/(func_P.Integral(0,80)/(h1.Integral()*h1.GetBinWidth(2)))
print(scale)
func_P.SetParameter(0,scale)

c.SetLogy()
func_P.Draw("same")
h1_s.SetLineColor(2)
h1_s.Draw("same")
c.Draw("")
# Out:
# 137672.07546002307
# <div id="root_plot_8"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
#        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-7.50000055879358,"fY1":-0.991837353022886,"fX2":67.5000005587936,"fY2":5.9162358088129,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":9.27999986171722,"fYtoAbsPixelk":404.231915578217,"fYtoPixelk":404.231915578217,"fYtoPixel":-68.3258542494313,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-7.50000055879358,"fPixeltoXk":-7.50000055879358,"fPixeltoX":0.107758622295384,"fAbsPixeltoYk":5.9162358088129,"fPixeltoYk":-0.991837353022886,"fPixeltoY":-0.0146357482242284,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":-0.301029995663981,"fUxmax":60,"fUymax":5.22542845145399,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":1,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":-0.301029995663981,"fX2":60,"fY2":5.22542845145399,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":50331656,"fName":"h1","fTitle":"h1","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":62,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":60,"fXmin":0,"fXmax":60,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":120058,"fTsumw":120056,"fTsumw2":120056,"fTsumwx":146622,"fTsumwx2":1920732,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPaveStats","fUniqueID":0,"fBits":50331657,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":51.0000015199185,"fY1":4.36191938857517,"fX2":66.0000019669533,"fY2":5.4672110697637,"fX1NDC":0.780000016093254,"fY1NDC":0.775000005960464,"fX2NDC":0.980000019073486,"fY2NDC":0.935000002384186,"fBorderSize":1,"fInit":1,"fShadowColor":1,"fCornerRadius":0,"fOption":"brNDC ...

# %%
dict_layers={}
for entrynum in tqdm(range(0, f.my_ttree.GetEntries())):
    f.my_ttree.GetEntry(entrynum)
    trigger=(getattr(f.my_ttree ,"L1"))
    if  (getattr(f.my_ttree ,"Tiger")<32):
        layer=0
    else:
        layer=1
    try:
        dict_layers[trigger][layer]+=getattr(f.my_ttree ,"Hits")
    except KeyError:
        dict_layers[trigger]=np.zeros((2))
        dict_layers[trigger][layer]+=getattr(f.my_ttree ,"Hits")
# Out:
# 100%|██████████| 120058/120058 [00:01<00:00, 81085.69it/s]

# %%
data_4_pd={
    "L1":[],
    "Layer":[],
    "Hits":[]    
}
for trigger in tqdm(range (105630,110519)):
    try:
        matrix=dict_layers[trigger]
    except KeyError:
        matrix=np.zeros((2))
    for layer in range(0,1):
        data_4_pd["L1"].append(trigger)
        data_4_pd["Layer"].append(layer)
        data_4_pd["Hits"].append(matrix[layer])
# Out:
# 100%|██████████| 4889/4889 [00:00<00:00, 302572.63it/s]

# %%
counts_pd=pd.DataFrame(data_4_pd)
root_pandas.to_root(counts_pd,"counts_tree_layers.root")

# %%
c=R.TCanvas()

# %%
f2=R.TFile("/home/alb/Desktop/elaborazioni_e_dati/analisi_run/Untitled Folder/counts_tree_layers.root")

# %%
h2=R.TH1F("h2","h2",50,0,50)
f2.my_ttree.Draw("Hits>>h2","Layer==0")
c.Draw()
# Out:
# <div id="root_plot_9"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
#        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-6.25000046566131,"fY1":-641.681297808982,"fX2":56.2500004656613,"fY2":5775.13129780898,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":11.1359998340607,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-0.0735567687175917,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-6.25000046566131,"fPixeltoXk":-6.25000046566131,"fPixeltoX":0.0897988519128199,"fAbsPixeltoYk":5775.13129780898,"fPixeltoYk":-641.681297808982,"fPixeltoY":-13.5949419398686,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":50,"fUymax":5133.45,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":50,"fY2":5133.45,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":50331656,"fName":"h2","fTitle":"h2","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":52,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":50,"fXmin":0,"fXmax":50,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":4889,"fTsumw":4889,"fTsumw2":4889,"fTsumwx":0,"fTsumwx2":0,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPaveStats","fUniqueID":0,"fBits":50331657,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":42.5000012665987,"fY1":4331.34850204212,"fX2":55.0000016391278,"fY2":5358.03849439269,"fX1NDC":0.780000016093254,"fY1NDC":0.775000005960464,"fX2NDC":0.980000019073486,"fY2NDC":0.935000002384186,"fBorderSize":1,"fInit":1,"fShadowColor":1,"fCornerRadius":0,"fOption":"brNDC","fName":"stats","fTextAngle":0,"fTextSize":0,"fTextAlign":12,"fTe ...
#        Core.draw("root_plot_9", obj, "");
#      }
#  );
# </script>

# %%
def possoniana(x,par):
    return par[0]*R.TMath.Poisson(x[0],h2.GetMean())

# %% [markdown]
# # Hit per trigger, tutto L1

# %%
func_P=R.TF1("possoniana",possoniana,0, 10,1)
func_P.SetParameter(0,1)

scale=1/(func_P.Integral(0,10)/(h2.Integral()*h2.GetBinWidth(2)))
print(scale)
func_P.SetParameter(0,scale)


func_P.Draw("same")
c.Draw("")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-180-0bc905865cdc> in <module>
#       2 func_P.SetParameter(0,1)
#       3
# ----> 4 scale=1/(func_P.Integral(0,10)/(h2.Integral()*h2.GetBinWidth(2)))
#       5 print(scale)
#       6 func_P.SetParameter(0,scale)
#
# ZeroDivisionError: float division by zero

# %%
h3=R.TH1F("h3","h3",1000,0,1000)
f2.my_ttree.Draw("Hits>>h3","Layer==1")
c.Draw()
# Out:
# <div id="root_plot_43"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
#        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-125.000009313226,"fY1":-0.131250009778888,"fX2":1125.00000931323,"fY2":1.18125000977889,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":0.556799991703033,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-359.619042260306,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-125.000009313226,"fPixeltoXk":-125.000009313226,"fPixeltoX":1.7959770382564,"fAbsPixeltoYk":1.18125000977889,"fPixeltoYk":-0.131250009778888,"fPixeltoY":-0.00278072038041902,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1000,"fUymax":1.05,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":1000,"fY2":1.05,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":50331656,"fName":"h3","fTitle":"h3","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":1002,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1000,"fXmin":0,"fXmax":1000,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":0,"fTsumw":0,"fTsumw2":0,"fTsumwx":0,"fTsumwx2":0,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPaveStats","fUniqueID":0,"fBits":50331657,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":850.000025331974,"fY1":0.885937513201498,"fX2":1100.00003278256,"fY2":1.09593751163688,"fX1NDC":0.780000016093254,"fY1NDC":0.775000005960464,"fX2NDC":0.980000019073486,"fY2NDC":0.935000002384186,"fBorderSize":1,"fInit":1,"fShadowColor":1,"fCornerRadius":0,"fOption":"brNDC","fName":"stats","fTextAngle":0,"fTextSize":0,"fTextAlign":12,"fTextC ...

# %%
def possoniana(x,par):
    return par[0]*R.TMath.Poisson(x[0],h3.GetMean())

# %% [markdown]
# # Hit per trigger, tutto L2

# %%
func_P=R.TF1("possoniana",possoniana,0, 1000,1)
func_P.SetParameter(0,1)

scale=1/(func_P.Integral(0,1000)/(h3.Integral()*h3.GetBinWidth(2)))
print(scale)
func_P.SetParameter(0,scale)


func_P.Draw("same")
c.Draw("")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-183-292b33aeab5f> in <module>
#       2 func_P.SetParameter(0,1)
#       3
# ----> 4 scale=1/(func_P.Integral(0,1000)/(h3.Integral()*h3.GetBinWidth(2)))
#       5 print(scale)
#       6 func_P.SetParameter(0,scale)
#
# ZeroDivisionError: float division by zero

# %%
h3.Integral(0,50)
# Out:
# 0.0

# %%
h3.Integral(50,800)
# Out:
# 0.0
