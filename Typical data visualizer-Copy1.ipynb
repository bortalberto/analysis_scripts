# %%
import ROOT as R
# %jsroot on

# %%
run_list=[411,412,410,409,404,405,406,408,397,396,392,393,376,375,355,351]

# %%
ch=R.TChain("tree")

# %%
for run in run_list:
    ch.Add("/media/alb/Removibile/dati/{}/Sub_RUN_ana_*".format(run))

# %%
c = R.TCanvas("c")

# %%
h=R.TH1I("h","h",2**16,0,2**16)
ch.Draw("tcoarse>>h","l1ts_min_tcoarse>1430 && (delta_coarse==25 || delta_coarse==26)","E1")
# Out:
# 19920812
# Warning in <TROOT::Append>: Replacing existing TH1: h (Potential memory leak).

# %%
c.Draw()
# Out:
# <div id="root_plot_19"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
h2=R.TH1I("h2","h2", 1000,0,2000)
for i in range (1,h.GetNbinsX()+1):
#     print("{} +/- {} ".format(h.GetBinContent(i),(h.GetBinError(i))))
    h2.Fill(h.GetBinContent(i))
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: h2 (Potential memory leak).

# %%
h2.Draw()
h2.Fit("gaus")
# Out:
#  FCN=1396.85 FROM MIGRAD    STATUS=CONVERGED      68 CALLS          69 TOTAL
#                      EDM=3.45269e-11    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.34234e+03   6.46620e+00   9.67611e-02   1.11907e-06
#    2  Mean         3.04137e+02   1.64214e-01   2.75790e-03   3.82904e-05
#    3  Sigma        3.81445e+01   1.05736e-01   1.26501e-05   2.70106e-03
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# Error in <TFitResultPtr>: TFitResult is empty - use the fit option S
# ...

# %%
c.Draw()
# Out:
# <div id="root_plot_20"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...
