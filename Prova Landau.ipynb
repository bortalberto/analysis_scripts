# %%
# !jt -t grade3 -fs 90 -tfs 14 -nfs 115 -cellw 80% -T
import ROOT as R
import array
import numpy as np
# %jsroot off
R.gStyle.SetOptStat(0)
c=R.TCanvas()

# %%
f1= R.TF1("f1","[0]*TMath::Landau(x,[1],[2]) ", 0,200)
f2= R.TF1("f2","[0]*TMath::Landau(x,[1],[2]) ", 0,200)
f3= R.TF1("f3","[0]*TMath::Landau(x,[1],[2]) ", 0,200)

# %%
f1.SetParameters(10,3,7)
f1.SetLineColor(1)
f2.SetParameters(10,6,10)
f2.SetLineColor(2)

f3.SetParameters(10,8,15)
f3.SetLineColor(3)

# %%
f1.Draw("")
f2.Draw("same")
f3.Draw("same")

c.Draw()

# %%
h1= R.TH1F("h1", 'charge',80,100,140 )
h2= R.TH1F("h2", 'charge',80,100,140 )
h3= R.TH1F("h2", 'charge',80,100,140 )
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: h1 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2 (Potential memory leak).

# %%
h1.FillRandom("f1",100000)
h1.SetLineColor(1)

h2.FillRandom("f2",100000)
h2.SetLineColor(2)

h3.FillRandom("f3",100000)
h3.SetLineColor(3)

# %%
h1.Draw()
h2.Draw("same")
h3.Draw("same")

c.Draw()
