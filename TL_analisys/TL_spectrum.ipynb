# %% [markdown]
# # Analisi spettrale rumore triggerlss

# %%
# !jt -t grade3 -fs 90 -tfs 15 -nfs 115 -cellw 80% -T
import ROOT as R
import array
import numpy as np
# Out:
# Welcome to JupyROOT 6.16/00

# %%
# %jsroot on

# %%
c = R.TCanvas("c")
R.gStyle.SetOptStat(0)

# %%
import FTT_spectrum as script

# %%
f=R.TFile("/home/alb/Desktop/elaborazioni_e_dati/analisi_run/TL_analisys/data_out/402/sub_0_G_2.root")
f.tree.Draw("timestamp>>h3(130000,0,13)")
c.Draw()
# Out:
# <div id="root_plot_1"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
ext_1=0
ext_2=3

# %%
h_trans_hz_1, h_spec_0, h_ori=script.extract_spectrum(f.tree,10000,ext_1,ext_2)
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: out_MAG (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h_trasf_hz_2 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h_spec (Potential memory leak).

# %%
h_trans_hz_1.Draw()
c.Draw()
# Out:
# <div id="root_plot_6"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
h_spec_0.Draw()
c.Draw()
# Out:
# <div id="root_plot_7"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
f=R.TFile("/home/alb/Desktop/elaborazioni_e_dati/analisi_run/TL_analisys/data_out/402/sub_1_G_2.root")
f.tree.Draw("timestamp>>h3(130000,0,13)")
c.Draw()
# Out:
# <div id="root_plot_4"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
ext_1=9.7
ext_2=12.7

# %%
h_trans_hz_1, h_spec_1, h_ori=script.extract_spectrum(f.tree,10000,ext_1,ext_2)
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: out_MAG (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h_trasf_hz_2 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h_spec (Potential memory leak).

# %%
h_spec_1.Draw()
h_spec_0.SetLineColor(3)
h_spec_0.SetLineStyle(1)
h_spec_0.Draw("same")
c.Draw()
# Out:
# <div id="root_plot_9"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
type (h_spec_0)
# Out:
# ROOT.TH1F
