# %%
import ROOT as R
# Out:
# Welcome to JupyROOT 6.16/00

# %%
run=396

# %%
ch=R.TChain("tree")

# %%
ch.Add("/home/alb/srv_lab/{}/Sub_RUN_ana_*".format(run))
# Out:
# 990

# %%
c = R.TCanvas("c")

# %%
ch.Draw("FEB_label:subRunNo","subRunNo>510 && subRunNo<530","colz")
# Out:
# 499431

# %%
c.Draw()

# %%
ch.Draw("FEB_label","subRunNo==520","colz")
# Out:
# 25903

# %%
c.Draw()

# %%
ch.Draw("FEB_label","subRunNo==519","colz")
c.Draw()

# %%
ch.Draw("FEB_label","subRunNo==518","colz")
c.Draw()

# %%
ch.Draw("FEB_label>>","subRunNo==510","")
c.Draw()

# %%
ch.Draw("tiger+gemroc*8:subRunNo","subRunNo<550 && subRunNo>500","colz")
c.Draw()

# %%
ch.Draw("tiger+gemroc*8>>h(90,0,90)","subRunNo==520","")
c.Draw()
